# %% [markdown]
# ## Python Libraries

# %%
# %%bash
#
# pip install -U pip
#
# pip install tensorflow
# pip install tensorflow-transform
# pip install tensorflow-model-analysis
# pip install tensorflow-hub
#
# pip install google-cloud-dataflow==2.3
# pip install python-snappy==5.0
# pip install -U google-cloud-bigquery
# Out:
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/5f/25/e52d3f31441505a5f3af41213346e5b6c221c9e086a166f3703d2ddaf940/pip-18.0-py2.py3-none-any.whl
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-18.0
# Requirement already satisfied: tensorflow in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.14.5)
# Requirement already satisfied: enum34>=1.1.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.1.6)
# Requirement already satisfied: mock>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: setuptools<=39.1.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (39.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: backports.weakref>=1.0rc1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.0.post1)
# Requirement already satisfied: tensorboard<1.10.0,>=1.9.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.9.0)
# Requirement already satisfied: gast>=0.2.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.13.0)
# Requirement already satisfied: six>=1.10.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: wheel in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (0.31.1)
# Requirement already satisfied: absl-py>=0.1.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: protobuf>=3.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: pbr>=0.11 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock>=2.0.0->tensorflow) (4.1.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock>=2.0.0->tensorflow) (1.0.2)
# Requirement already satisfied: futures>=3.1.1; python_version < "3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (3.2.0)
# Requirement already satisfied: werkzeug>=0.11.10 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (2.6.11)
# Collecting tensorflow-transform
# Requirement already satisfied: numpy<2,>=1.13.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform) (1.14.5)
# Requirement already satisfied: absl-py>=0.1.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform) (0.2.2)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform) (2.5.0)
# Requirement already satisfied: protobuf<4,>=3.6.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform) (3.6.0)
# Requirement already satisfied: six<2,>=1.10 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform) (1.11.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2.1.0)
# Requirement already satisfied: dill==0.2.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.2.6)
# Requirement already satisfied: typing<3.7.0,>=3.6.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.6.4)
# Requirement already satisfied: avro<2.0.0,>=1.8.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.8.2)
# Requirement already satisfied: future<1.0.0,>=0.16.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.16.0)
# Requirement already satisfied: pyvcf<0.7.0,>=0.6.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.6.8)
# Requirement already satisfied: pytz>=2018.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2018.5)
# Requirement already satisfied: grpcio<2,>=1.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.13.0)
# Requirement already satisfied: futures<4.0.0,>=3.1.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.2.0)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2.0.0)
# Requirement already satisfied: pyyaml<4.0.0,>=3.12 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.13)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.7)
# Requirement already satisfied: httplib2<0.10,>=0.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.9.2)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.0.0)
# Requirement already satisfied: google-apitools<=0.5.20,>=0.5.18; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.5.20)
# Requirement already satisfied: proto-google-cloud-pubsub-v1==0.15.4; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.15.4)
# Requirement already satisfied: google-cloud-bigquery==0.25.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.25.0)
# Requirement already satisfied: google-cloud-pubsub==0.26.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.26.0)
# Requirement already satisfied: googledatastore==7.0.1; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (7.0.1)
# Requirement already satisfied: proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.90.4)
# Requirement already satisfied: setuptools in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from protobuf<4,>=3.6.0->tensorflow-transform) (39.1.0)
# Requirement already satisfied: docopt in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2.19.1)
# Requirement already satisfied: enum34>=1.0.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from grpcio<2,>=1.8->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.1.6)
# Requirement already satisfied: pbr>=0.11 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (4.1.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.0.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.4.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.2.2)
# Requirement already satisfied: rsa>=3.1.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.4.2)
# Requirement already satisfied: fasteners>=0.14 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-apitools<=0.5.20,>=0.5.18; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.14.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from proto-google-cloud-pubsub-v1==0.15.4; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.5.3)
# Requirement already satisfied: google-cloud-core<0.26dev,>=0.25.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.25.0)
# Requirement already satisfied: gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.15.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2018.4.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2.7)
# Requirement already satisfied: monotonic>=0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from fasteners>=0.14->google-apitools<=0.5.20,>=0.5.18; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.5)
# Requirement already satisfied: google-auth-httplib2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.0.3)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (1.5.0)
# Requirement already satisfied: google-gax<0.16dev,>=0.15.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.15.16)
# Requirement already satisfied: grpc-google-iam-v1<0.12dev,>=0.11.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (0.11.4)
# Requirement already satisfied: cachetools>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (2.1.0)
# Requirement already satisfied: ply==3.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.5->tensorflow-transform) (3.8)
# Installing collected packages: tensorflow-transform
# Successfully installed tensorflow-transform-0.8.0
# Collecting tensorflow-model-analysis
# Requirement already satisfied: six<2,>=1.9 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-model-analysis) (1.11.0)
# Requirement already satisfied: protobuf<4,>=3.5.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-model-analysis) (3.6.0)
# Collecting ipywidgets<8,>=7.0 (from tensorflow-model-analysis)
#   Downloading https://files.pythonhosted.org/packages/f0/5d/868df21e3b004a5a61294cab70e1f6f44986933eb3aa9c396dfd5112acb2/ipywidgets-7.3.0-py2.py3-none-any.whl (109kB)
# Collecting jupyter<2,>=1.0 (from tensorflow-model-analysis)
#   Using cached https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting grpc-google-iam-v1==0.11.1 (from tensorflow-model-analysis)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-model-analysis) (2.5.0)
# Requirement already satisfied: numpy<2,>=1.10 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-model-analysis) (1.14.5)
# Requirement already satisfied: tensorflow-transform<1,>=0.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-model-analysis) (0.8.0)
# Requirement already satisfied: setuptools in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from protobuf<4,>=3.5.2->tensorflow-model-analysis) (39.1.0)
# Requirement already satisfied: ipython<6.0.0,>=4.0.0; python_version < "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipywidgets<8,>=7.0->tensorflow-model-analysis) (5.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.8.2)
# Collecting widgetsnbextension~=3.3.0 (from ipywidgets<8,>=7.0->tensorflow-model-analysis)
#   Downloading https://files.pythonhosted.org/packages/b9/43/f6ff09448f7b961e102fd75b7e46a5d44b68b9746bb1ab5c4be64c3e236d/widgetsnbextension-3.3.0-py2.py3-none-any.whl (2.2MB)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.4.0)
# Collecting jupyter-console (from jupyter<2,>=1.0->tensorflow-model-analysis)
#   Using cached https://files.pythonhosted.org/packages/77/82/6469cd7fccf7958cbe5dce2e623f1e3c5e27f1bb1ad36d90519bc2d5d370/jupyter_console-5.2.0-py2.py3-none-any.whl
# Requirement already satisfied: notebook in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from jupyter<2,>=1.0->tensorflow-model-analysis) (5.6.0)
# Requirement already satisfied: nbconvert in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from jupyter<2,>=1.0->tensorflow-model-analysis) (5.3.1)
# Collecting qtconsole (from jupyter<2,>=1.0->tensorflow-model-analysis)
#   Using cached https://files.pythonhosted.org/packages/90/ff/047e0dca2627b162866920e7aa93f04523c0ae81e5c67060eec85701992d/qtconsole-4.3.1-py2.py3-none-any.whl
# Requirement already satisfied: grpcio<2.0.0dev,>=1.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (1.13.0)
# Requirement already satisfied: oauth2client<4.0.0dev,>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (3.0.0)
# Requirement already satisfied: googleapis-common-protos[grpc]<2.0.0dev,>=1.3.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (1.5.3)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2.1.0)
# Requirement already satisfied: dill==0.2.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.2.6)
# Requirement already satisfied: typing<3.7.0,>=3.6.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (3.6.4)
# Requirement already satisfied: avro<2.0.0,>=1.8.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.8.2)
# Requirement already satisfied: future<1.0.0,>=0.16.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.16.0)
# Requirement already satisfied: pyvcf<0.7.0,>=0.6.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.6.8)
# Requirement already satisfied: pytz>=2018.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2018.5)
# Requirement already satisfied: futures<4.0.0,>=3.1.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (3.2.0)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2.0.0)
# Requirement already satisfied: pyyaml<4.0.0,>=3.12 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (3.13)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.7)
# Requirement already satisfied: httplib2<0.10,>=0.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.9.2)
# Requirement already satisfied: google-apitools<=0.5.20,>=0.5.18; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.5.20)
# Requirement already satisfied: proto-google-cloud-pubsub-v1==0.15.4; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.15.4)
# Requirement already satisfied: google-cloud-bigquery==0.25.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.25.0)
# Requirement already satisfied: google-cloud-pubsub==0.26.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.26.0)
# Requirement already satisfied: googledatastore==7.0.1; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (7.0.1)
# Requirement already satisfied: proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0; extra == "gcp" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.90.4)
# Requirement already satisfied: absl-py>=0.1.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-transform<1,>=0.6->tensorflow-model-analysis) (0.2.2)
# Requirement already satisfied: simplegeneric>0.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.8.1)
# Requirement already satisfied: backports.shutil-get-terminal-size; python_version == "2.7" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (1.0.0)
# Requirement already satisfied: pygments in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (2.2.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.6.0)
# Requirement already satisfied: pickleshare in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.7.4)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (1.0.15)
# Requirement already satisfied: decorator in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.3.0)
# Requirement already satisfied: pathlib2; python_version == "2.7" or python_version == "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (2.3.2)
# Requirement already satisfied: ipython-genutils in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from traitlets>=4.3.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.2.0)
# Requirement already satisfied: enum34; python_version == "2.7" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from traitlets>=4.3.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (1.1.6)
# Requirement already satisfied: jupyter-client in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (5.1)
# Requirement already satisfied: jupyter-core in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0->tensorflow-model-analysis) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0->tensorflow-model-analysis) (2.6.0)
# Requirement already satisfied: terminado>=0.8.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (0.8.1)
# Requirement already satisfied: jinja2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (2.10)
# Requirement already satisfied: ipaddress; python_version == "2.7" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (1.0.22)
# Requirement already satisfied: pyzmq>=17 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (17.1.0)
# Requirement already satisfied: prometheus-client in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (0.3.0)
# Requirement already satisfied: Send2Trash in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (1.5.0)
# Requirement already satisfied: mistune>=0.7.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (0.8.3)
# Requirement already satisfied: bleach in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (2.1.3)
# Requirement already satisfied: testpath in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (0.3.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (0.2.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<4.0.0dev,>=2.0.0->grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (0.4.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<4.0.0dev,>=2.0.0->grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (0.2.2)
# Requirement already satisfied: rsa>=3.1.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<4.0.0dev,>=2.0.0->grpc-google-iam-v1==0.11.1->tensorflow-model-analysis) (3.4.2)
# Requirement already satisfied: docopt in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2.19.1)
# Requirement already satisfied: pbr>=0.11 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (4.1.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.0.2)
# Requirement already satisfied: fasteners>=0.14 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-apitools<=0.5.20,>=0.5.18; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.14.1)
# Requirement already satisfied: google-cloud-core<0.26dev,>=0.25.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.25.0)
# Requirement already satisfied: gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.15.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from pexpect; sys_platform != "win32"->ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.1.7)
# Requirement already satisfied: scandir; python_version < "3.5" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from pathlib2; python_version == "2.7" or python_version == "3.3"->ipython<6.0.0,>=4.0.0; python_version < "3.3"->ipywidgets<8,>=7.0->tensorflow-model-analysis) (1.7)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (2.7.3)
# Requirement already satisfied: backports-abc>=0.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tornado>=4.0->ipykernel>=4.5.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (0.5)
# Requirement already satisfied: singledispatch in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tornado>=4.0->ipykernel>=4.5.1->ipywidgets<8,>=7.0->tensorflow-model-analysis) (3.4.0.3)
# Requirement already satisfied: functools32; python_version == "2.7" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.0->tensorflow-model-analysis) (3.2.3.post2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from jinja2->notebook->jupyter<2,>=1.0->tensorflow-model-analysis) (1.0)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from bleach->nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (1.0.1)
# Requirement already satisfied: configparser>=3.5; python_version == "2.7" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from entrypoints>=0.2.2->nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2018.4.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2.7)
# Requirement already satisfied: monotonic>=0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from fasteners>=0.14->google-apitools<=0.5.20,>=0.5.18; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.5)
# Requirement already satisfied: google-auth-httplib2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.0.3)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (1.5.0)
# Requirement already satisfied: google-gax<0.16dev,>=0.15.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (0.15.16)
# Requirement already satisfied: webencodings in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->jupyter<2,>=1.0->tensorflow-model-analysis) (0.5.1)
# Requirement already satisfied: cachetools>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-cloud-core<0.26dev,>=0.25.0->google-cloud-bigquery==0.25.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (2.1.0)
# Requirement already satisfied: ply==3.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0; extra == "gcp"->apache-beam[gcp]<3,>=2.4->tensorflow-model-analysis) (3.8)
# Installing collected packages: widgetsnbextension, ipywidgets, jupyter-console, qtconsole, jupyter, grpc-google-iam-v1, tensorflow-model-analysis
#   Found existing installation: grpc-google-iam-v1 0.11.4
#     Uninstalling grpc-google-iam-v1-0.11.4:
#       Successfully uninstalled grpc-google-iam-v1-0.11.4
# Successfully installed grpc-google-iam-v1-0.11.1 ipywidgets-7.3.0 jupyter-1.0.0 jupyter-console-5.2.0 qtconsole-4.3.1 tensorflow-model-analysis-0.6.0 widgetsnbextension-3.3.0
# Collecting tensorflow-hub
#   Downloading https://files.pythonhosted.org/packages/aa/8e/ab0d5cf0f2dc2ed1c645bf1cb4acc7beeb0be5a51ebb0c91cbb23eb1fe10/tensorflow_hub-0.1.0-py2.py3-none-any.whl (53kB)
# Requirement already satisfied: protobuf>=3.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-hub) (3.6.0)
# Requirement already satisfied: numpy>=1.12.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-hub) (1.14.5)
# Requirement already satisfied: six>=1.10.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from tensorflow-hub) (1.11.0)
# Requirement already satisfied: setuptools in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from protobuf>=3.4.0->tensorflow-hub) (39.1.0)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.1.0
# Collecting google-cloud-dataflow==2.3
#   Downloading https://files.pythonhosted.org/packages/4a/91/6c7f5e51f521892ed211e03650131a03604665cf5252c591fa3ab421b757/google-cloud-dataflow-2.3.0.tar.gz
# Collecting apache-beam[gcp]==2.3.0 (from google-cloud-dataflow==2.3)
#   Downloading https://files.pythonhosted.org/packages/95/fe/333b02eb50b4d843b3030bc8c65257f47cb715b054693cd375f5c37e2f44/apache-beam-2.3.0.zip (1.0MB)
# Requirement already satisfied: avro<2.0.0,>=1.8.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.8.2)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.7)
# Requirement already satisfied: dill==0.2.6 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.2.6)
# Requirement already satisfied: grpcio<2,>=1.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.13.0)
# Requirement already satisfied: httplib2<0.10,>=0.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.9.2)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (2.0.0)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.0.0)
# Requirement already satisfied: protobuf<4,>=3.5.0.post1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.6.0)
# Requirement already satisfied: pyyaml<4.0.0,>=3.12 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.13)
# Requirement already satisfied: pyvcf<0.7.0,>=0.6.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.6.8)
# Requirement already satisfied: six<1.12,>=1.9 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.11.0)
# Requirement already satisfied: typing<3.7.0,>=3.6.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.6.4)
# Requirement already satisfied: futures<4.0.0,>=3.1.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.2.0)
# Collecting hdfs3<0.4.0,>=0.3.0 (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3)
#   Downloading https://files.pythonhosted.org/packages/52/fa/a4e4d26c1a5f1fbd29eae9d7a602c872f0fbe4cfcbb4c72497be5d4f2b3a/hdfs3-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: google-apitools<=0.5.20,>=0.5.18 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.5.20)
# Requirement already satisfied: proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.90.4)
# Requirement already satisfied: googledatastore==7.0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (7.0.1)
# Requirement already satisfied: google-cloud-pubsub==0.26.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.26.0)
# Requirement already satisfied: google-cloud-bigquery==0.25.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.25.0)
# Requirement already satisfied: enum34>=1.0.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from grpcio<2,>=1.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.1.6)
# Requirement already satisfied: pbr>=0.11 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (4.1.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.0.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.4.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.2.2)
# Requirement already satisfied: rsa>=3.1.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.4.2)
# Requirement already satisfied: setuptools in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from protobuf<4,>=3.5.0.post1->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (39.1.0)
# Requirement already satisfied: fasteners>=0.14 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-apitools<=0.5.20,>=0.5.18->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.14.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.5.3)
# Requirement already satisfied: gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.15.4)
# Requirement already satisfied: google-cloud-core<0.26dev,>=0.25.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.25.0)
# Requirement already satisfied: monotonic>=0.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from fasteners>=0.14->google-apitools<=0.5.20,>=0.5.18->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.5)
# Requirement already satisfied: proto-google-cloud-pubsub-v1[grpc]<0.16dev,>=0.15.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.15.4)
# Requirement already satisfied: google-gax<0.16dev,>=0.15.7 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.15.16)
# Requirement already satisfied: grpc-google-iam-v1<0.12dev,>=0.11.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.11.1)
# Requirement already satisfied: google-auth-httplib2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.0.3)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-core<0.26dev,>=0.25.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.5.0)
# Requirement already satisfied: requests<3.0dev,>=2.13.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (2.19.1)
# Requirement already satisfied: ply==3.8 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.8)
# Requirement already satisfied: future<0.17dev,>=0.16.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (0.16.0)
# Requirement already satisfied: cachetools>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-cloud-core<0.26dev,>=0.25.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (2018.4.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.7->gapic-google-cloud-pubsub-v1<0.16dev,>=0.15.0->google-cloud-pubsub==0.26.0->apache-beam[gcp]==2.3.0->google-cloud-dataflow==2.3) (2.7)
# Building wheels for collected packages: google-cloud-dataflow, apache-beam
#   Running setup.py bdist_wheel for google-cloud-dataflow: started
#   Running setup.py bdist_wheel for google-cloud-dataflow: finished with status 'done'
#   Stored in directory: /Users/agravat/Library/Caches/pip/wheels/99/15/e0/95f221a6b0934cc11cd3a66b7478021d510c562cec5daae83b
#   Running setup.py bdist_wheel for apache-beam: started
#   Running setup.py bdist_wheel for apache-beam: finished with status 'done'
#   Stored in directory: /Users/agravat/Library/Caches/pip/wheels/e6/08/9f/99e1b88b8a6f9f00873ab7512cfa90303be53f156e384aedd4
# Successfully built google-cloud-dataflow apache-beam
# Installing collected packages: hdfs3, apache-beam, google-cloud-dataflow
#   Found existing installation: apache-beam 2.5.0
#     Uninstalling apache-beam-2.5.0:
#       Successfully uninstalled apache-beam-2.5.0
#   Found existing installation: google-cloud-dataflow 2.5.0
#     Uninstalling google-cloud-dataflow-2.5.0:
#       Successfully uninstalled google-cloud-dataflow-2.5.0
# Successfully installed apache-beam-2.3.0 google-cloud-dataflow-2.3.0 hdfs3-0.3.0
# Collecting python-snappy==5.0
# Collecting google-cloud-bigquery
#   Downloading https://files.pythonhosted.org/packages/0f/9f/45a7e4d1731d6b2cc0f6011d763fa4eec85956515306f47ecc50b38bdf6d/google_cloud_bigquery-1.4.0-py2.py3-none-any.whl (76kB)
# Collecting google-api-core<2.0.0dev,>=1.0.0 (from google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/d2/03/a83c6d0efa63a13d085b81927fdc9e12ffb98aa0f67798a7573fc6b231e2/google_api_core-1.2.1-py2.py3-none-any.whl (50kB)
# Collecting google-cloud-core<0.29dev,>=0.28.0 (from google-cloud-bigquery)
#   Using cached https://files.pythonhosted.org/packages/0f/41/ae2418b4003a14cf21c1c46d61d1b044bf02cf0f8f91598af572b9216515/google_cloud_core-0.28.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: google-resumable-media>=0.2.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-cloud-bigquery) (0.3.1)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (39.1.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (2.19.1)
# Requirement already satisfied, skipping upgrade: pytz in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (2018.5)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.5.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (1.5.3)
# Requirement already satisfied, skipping upgrade: google-auth<2.0.0dev,>=0.4.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (1.5.0)
# Requirement already satisfied, skipping upgrade: futures>=3.2.0; python_version < "3.2" in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (3.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (1.11.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (3.6.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (2018.4.16)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.24,>=1.21.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (1.23)
# Requirement already satisfied, skipping upgrade: idna<2.8,>=2.5 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (2.7)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (3.4.2)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (2.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (0.2.2)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages (from rsa>=3.1.4->google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery) (0.4.3)
# Installing collected packages: google-api-core, google-cloud-core, google-cloud-bigquery
#   Found existing installation: google-api-core 0.1.4
#     Uninstalling google-api-core-0.1.4:
#       Successfully uninstalled google-api-core-0.1.4
#   Found existing installation: google-cloud-core 0.25.0
#     Uninstalling google-cloud-core-0.25.0:
#       Successfully uninstalled google-cloud-core-0.25.0
#   Found existing installation: google-cloud-bigquery 0.25.0
#     Uninstalling google-cloud-bigquery-0.25.0:
#       Successfully uninstalled google-cloud-bigquery-0.25.0
# Successfully installed google-api-core-1.2.1 google-cloud-bigquery-1.4.0 google-cloud-core-0.28.1
# google-cloud-storage 1.6.0 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-firestore 0.28.0 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-bigtable 0.28.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-resource-manager 0.28.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-monitoring 0.28.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-error-reporting 0.28.0 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-translate 1.3.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement google-cloud-core[grpc]<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-speech 0.30.0 has requirement google-cloud-core[grpc]<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-runtimeconfig 0.28.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-bigquery<0.29dev,>=0.28.0, but you'll have google-cloud-bigquery 0.25.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-pubsub<0.31dev,>=0.30.0, but you'll have google-cloud-pubsub 0.26.0 which is incompatible.
# google-cloud-trace 0.17.0 has requirement google-cloud-core[grpc]<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-logging 1.4.0 has requirement google-cloud-core[grpc]<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-dns 0.28.0 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-datastore 1.4.0 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement google-cloud-core[grpc]<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement grpc-google-iam-v1<0.12dev,>=0.11.4, but you'll have grpc-google-iam-v1 0.11.1 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-bigquery<0.29dev,>=0.28.0, but you'll have google-cloud-bigquery 0.25.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-core<0.29dev,>=0.28.0, but you'll have google-cloud-core 0.25.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-pubsub<0.31dev,>=0.30.0, but you'll have google-cloud-pubsub 0.26.0 which is incompatible.
# tensorflow-model-analysis 0.6.0 has requirement apache-beam[gcp]<3,>=2.4, but you'll have apache-beam 2.3.0 which is incompatible.
# tensorflow-transform 0.8.0 has requirement apache-beam[gcp]<3,>=2.5, but you'll have apache-beam 2.3.0 which is incompatible.
#   Could not find a version that satisfies the requirement python-snappy==5.0 (from versions: 0.2, 0.2.1, 0.2.2, 0.3, 0.3.1, 0.3.2, 0.4, 0.5, 0.5.1, 0.5.2, 0.5.3)
# No matching distribution found for python-snappy==5.0
# google-cloud-pubsub 0.26.0 has requirement google-cloud-core<0.26dev,>=0.25.0, but you'll have google-cloud-core 0.28.1 which is incompatible.
# google-cloud-storage 1.6.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-firestore 0.28.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-bigtable 0.28.1 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement grpc-google-iam-v1<0.12dev,>=0.11.4, but you'll have grpc-google-iam-v1 0.11.1 which is incompatible.
# google-cloud-vision 0.29.0 has requirement google-api-core<0.2.0dev,>=0.1.0, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-error-reporting 0.28.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-speech 0.30.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud 0.33.1 has requirement google-api-core<0.2.0dev,>=0.1.2, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-bigquery<0.29dev,>=0.28.0, but you'll have google-cloud-bigquery 1.4.0 which is incompatible.
# google-cloud 0.33.1 has requirement google-cloud-pubsub<0.31dev,>=0.30.0, but you'll have google-cloud-pubsub 0.26.0 which is incompatible.
# google-cloud-trace 0.17.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-logging 1.4.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-dns 0.28.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.
# google-cloud-datastore 1.4.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.2.1 which is incompatible.

# %% [markdown]
# ## Enable TFMA in Jupyter

# %%
# %%bash
#
# jupyter nbextension enable --py widgetsnbextension
# jupyter nbextension install --py --symlink tensorflow_model_analysis --user
# jupyter nbextension enable --py tensorflow_model_analysis
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
# /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37: ImportWarning: Not importing directory '/Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/optimize/lbfgsb': missing __init__.py
#   from .lbfgsb import _minimize_lbfgsb
# Installing /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/tensorflow_model_analysis/static -> tfma_widget_js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable tensorflow_model_analysis --user --py
#
# /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
# /Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37: ImportWarning: Not importing directory '/Users/agravat/Work/git/femur-enhancers/venv/lib/python2.7/site-packages/scipy/optimize/lbfgsb': missing __init__.py
#   from .lbfgsb import _minimize_lbfgsb
# Enabling notebook extension tfma_widget_js/extension...
#       - Validating: OK

# %% [markdown]
# ## Install Facets

# %%
# %%bash
#
# git clone https://github.com/PAIR-code/facets
# cd facets
# jupyter nbextension install facets-dist/ --user
# Out:
# Cloning into 'facets'...
# Out of date: /Users/agravat/Library/Jupyter/nbextensions/facets-dist/facets-jupyter.html
# Copying: /Users/agravat/Work/git/datalab-notebooks/GCP ML Labs/facets/facets-dist/facets-jupyter.html -> /Users/agravat/Library/Jupyter/nbextensions/facets-dist/facets-jupyter.html
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable <the entry point> --user
