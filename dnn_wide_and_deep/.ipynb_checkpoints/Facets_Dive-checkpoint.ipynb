# %%
# Load UCI census and convert to json for sending to the visualization
import pandas as pd
features = ['hashmonth','session_year','session_month','session_day','customer_id','BOOK_CONF_ID','grp_book_num',
            'visid','sail_year','sail_month','sail_day','num_passengers','new_customer','ship','destination',
            'departure','cabin_type','balcony','deck','payment_class','total_cost','per_person_cost','geo_city',
            'geo_region','hier1','channelGrouping','source_source','source_medium','source_campaign',
            'ga_totals_hits','deviceCategory','delta_sail','orig_gst_source','cd_duration','cd_cabin_type',
            'cd_user_segment','cd_user_segment_1','cd_ship','courtesy_holds_redeemed','dups']

# Load dataframe from external CSV and add header information
df = pd.read_csv("data/eval2.csv",
    names=features, # name features for header row
    sep=r',', # separator used in this dataset
    engine='python',
    skiprows=[0], # skip first row without data 
    na_values="?") # add ? where data is missing

# set the sprite_size based on the number of records in dataset,
# larger datasets can crash the browser if the size is too large (>50000)
sprite_size = 32 if len(df.index)>50000 else 96
print(df.shape)
jsonstr = df.to_json(orient='records')
# Out:
# (3090, 40)

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML

# Create Facets template  
HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive sprite-image-width="{sprite_size}" sprite-image-height="{sprite_size}" id="elem" height="600"></facets-dive>
        <script>
          document.querySelector("#elem").data = {jsonstr};
        </script>"""

# Load the json dataset and the sprite_size into the template
html = HTML_TEMPLATE.format(jsonstr=jsonstr, sprite_size=sprite_size)

# Display the template
display(HTML(html))
# Out:
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive sprite-image-width="96" sprite-image-height="96" id="elem" height="600"></facets-dive>
#         <script>
#           document.querySelector("#elem").data = [{"hashmonth":1301359705703831064,"session_year":2018,"session_month":1,"session_day":23,"customer_id":9006603239,"BOOK_CONF_ID":"1CCK95","grp_book_num":"1CCK95","visid":"32523111697689497226917530177618597934","sail_year":2019,"sail_month":1,"sail_day":5,"num_passengers":2.0,"new_customer":"Repeat","ship":"carnival freedom","destination":"western caribbean","departure":"galveston_tx","cabin_type":"aft-view extended balcony","balcony":"balcony","deck":"verandah","payment_class":null,"total_cost":2045.8,"per_person_cost":1022.9,"geo_city":"mckinney","geo_region":"tx","hier1":"carnival.com:booking:courtesy_hold_confirmation","channelGrouping":"Affiliates","source_source":"12","source_medium":"affiliates","source_campaign":"medallia","ga_totals_hits":181,"deviceCategory":"tablet","delta_sail":347,"orig_gst_source":"Carnival.com","cd_duration":null,"cd_cabin_type":"single-cabin","cd_user_segment":"booked","cd_user_segment_1":"booked","cd_ship":null,"courtesy_holds_redeemed":1,"dups":1},{"hashmonth":6912397349630106969,"session_year":2018,"session_month":4,"session_day":10,"customer_id":9050660936,"BOOK_CONF_ID":"1XWJ66","grp_book_num":"1XWJ66","visid":"32623993543100405544611687341277324765","sail_year":2018,"sail_month":7,"sail_day":28,"num_passengers":2.0,"new_customer":"Repeat","ship":"carnival freedom","destination":"eastern_caribbean","departure":"galveston_tx","cabin_type":"balcony","balcony":"balcony","deck":"upper","payment_class":null,"total_cost":2862.1,"per_person_cost":1431.05,"geo_city":"galveston","geo_region":"tx","hier1":"carnival.com:booking:courtesy_hold_confirmation","channelGrouping":"Affiliates","source_source":"12","source_medium":"affiliates","source_campaign":"medallia","ga_totals_hits":8,"deviceCategory":"mobile","delta_sail":142,"orig_gst_source":"Carnival.com","cd_duration":null,"cd_cabin_type":null,"cd_user_segment":"booked","cd_user_segment_1":"booked","cd_ship":null,"courtesy_holds_redeemed":1,"dups":1},{"hashmonth":297036804864949974,"session_year":2018,"session_month":5,"session_day":4,"customer_id":9000121596,"BOOK_CONF_ID":"2TMN35","grp_book_num":"2TMN35","visid":"32673232486981944906917530179766063469","sail_year":2019,"sail_month":4,"sail_day":28,"num_passengers":5.0,"new_customer":"Repeat","ship":"carnival magic","destination":"western caribbean","departure":"miami_fl","cabin_type":"ocean view","balcony":null,"deck":"riviera","payment_class":null,"total_cost":2765.0,"per_person_cost":553.0,"geo_city":"corbin","geo_region":"ky","hier1":"carnival.com:booking:courtesy_hold_confirmation","channelGrouping":"Affiliates","source_source":"12","source_medium":"affiliates","source_campaign":"medallia","ga_totals_hits":47,"deviceCategory":"mobile","delta_sail":359,"orig_gst_source":"Carnival.com","cd_duration":null,"cd_cabin_type":"single-cabin","cd_user_segment":"booked","cd_user_segment_1":"booked","cd_ship":null,"courtesy_holds_redeemed":0,"dups":1},{"hashmonth":5453041111614569454,"session_year":2018,"session_month":4,"session_day":27,"customer_id":9007159699,"BOOK_CONF_ID":"2RRR51","grp_book_num":"2RRR51","visid":"32676185985664447494611705344706498010","sail_year":2019,"sail_month":1,"sail_day":13,"num_passengers":2.0,"new_customer":"Repeat","ship":"carnival miracle","destination":"western caribbean","departure":"tampa_fl","cabin_type":"balcony (obstructed view)","balcony":"balcony","deck":"upper","payment_class":null,"total_cost":1488.8,"per_person_cost":744.4,"geo_city":"high point","geo_region":"nc","hier1":"carnival.com:booking:courtesy_hold_confirmation","channelGrouping":"Affiliates","source_source":"12","source_medium":"affiliates","source_campaign":"medallia","ga_totals_hits":9,"deviceCategory":"mobile","delta_sail":261,"orig_gst_source":"Carnival.com","cd_duration":null,"cd_cabin_type":null,"cd_user_segment":"ch booked guest","cd_user_segment_1":"booked","cd_ship":null,"courtesy_holds_redeemed":0,"dups":1},{"hashmonth":3766708300370931199,"se ...
