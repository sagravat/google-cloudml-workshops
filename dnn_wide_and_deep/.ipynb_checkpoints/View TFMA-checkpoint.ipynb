# %%
import apache_beam as beam  
import os
import shutil
import tensorflow as tf
import tensorflow_model_analysis as tfma
from tensorflow_transform.beam.tft_beam_io import transform_fn_io
from tensorflow_transform.coders import example_proto_coder
from tensorflow_transform.saved import saved_transform_io
from tensorflow_transform.tf_metadata import dataset_schema
import params
import numpy as np

# %%
tfma_result_1 = tfma.load_eval_result(output_path=params.Params.TFMA_OUT+"/15")

# %%
FEATURE_COLUMN_CROSS_SPEC = tfma.SingleSliceSpec(columns=['geo_city'])

# %%
tfma.view.render_slicing_metrics(tfma_result_1, slicing_spec=FEATURE_COLUMN_CROSS_SPEC)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'post_export_metrics/example_count'}, data=[{'metrics': {u'accuracy_baseline': 0.6666666269302368, u'recall': 0.0, u'auc': 9.9999863323319e-07, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.3333333432674408, u'average_loss': 0.8403602242469788, 'post_export_metrics/example_count': 3.0, u'prediction/mean': 0.2521347999572754, u'auc_precision_recall': 0.16666686534881592, u'accuracy': 0.6666666865348816}, 'slice': 'geo_city:chula vista'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.0, u'micro_accuracy': 0.0, u'precision': 0.0, u'label/mean': 1.0, u'average_loss': 0.8178895711898804, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.4413621127605438, u'auc_precision_recall': 0.9999989867210388, u'accuracy': 0.0}, 'slice': 'geo_city:frederick'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 1.0, u'auc': 0.0, u'micro_accuracy': 0.5, u'precision': 1.0, u'label/mean': 1.0, u'average_loss': 0.149098202586174, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.8614845275878906, u'auc_precision_recall': 0.9999989867210388, u'accuracy': 1.0}, 'slice': 'geo_city:nicosia'}, {'metrics': {u'accuracy_baseline': 0.6666666269302368, u'recall': 0.0, u'auc': 0.9999995231628418, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.3333333432674408, u'average_loss': 0.4978727102279663, 'post_export_metrics/example_count': 3.0, u'prediction/mean': 0.17246760427951813, u'auc_precision_recall': 0.9999989867210388, u'accuracy': 0.6666666865348816}, 'slice': 'geo_city:hammond'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.0, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 3.5674195289611816, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.9717714190483093, u'auc_precision_recall': 0.0, u'accuracy': 0.0}, 'slice': 'geo_city:bridgeton'}, {'metrics': {u'accuracy_baseline': 0.6666666269302368, u'recall': 0.0, u'auc': 0.9999995231628418, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.3333333432674408, u'average_loss': 0.6906594634056091, 'post_export_metrics/example_count': 3.0, u'prediction/mean': 0.14159978926181793, u'auc_precision_recall': 0.9999989867210388, u'accuracy': 0.6666666865348816}, 'slice': 'geo_city:hayward'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999997019767761, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.426497220993042, 'post_export_metrics/example_count': 3.0, u'prediction/mean': 0.33945026993751526, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'geo_city:biloxi'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999995231628418, u'micro_accuracy': 0.25, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.5454093813896179, 'post_export_metrics/example_count': 2.0, u'prediction/mean': 0.3866285979747772, u'auc_precision_recall': 0.0, u'accuracy': 0.5}, 'slice': 'geo_city:murrells inlet'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.28157666325569153, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.24540694057941437, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'geo_city:hermosa beach'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999995231628418, u'micro_accuracy': 0.25, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 1.5862075090408325, 'post_export_metrics/example_count': 2.0, u'prediction/mean': 0.5526610612869263, u'auc_precision_recall': 0.0, u'accuracy': 0.5}, 'slice': 'geo_city:panama city'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.3870663344860077, 'post_export_metrics/example_count': 1.0, u'prediction/m ...

# %%
tfma_result_2 = tfma.load_eval_result(output_path=params.Params.TFMA_OUT+"/2")

# %%
tfma.view.render_slicing_metrics(tfma_result_2, slicing_spec=FEATURE_COLUMN_CROSS_SPEC)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'post_export_metrics/example_count'}, data=[{'metrics': {u'accuracy_baseline': 0.5, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.5, u'average_loss': 0.7362021207809448, 'post_export_metrics/example_count': 2.0, u'prediction/mean': 0.25650930404663086, u'auc_precision_recall': 0.9999989867210388, u'accuracy': 0.5}, 'slice': 'destination_X_geo_city:eastern_caribbean_X_new haven'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.3568873107433319, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.3001486361026764, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:western caribbean_X_jacksons gap'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.29742708802223206, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.25727325677871704, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:mexican_riviera_X_menifee'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.409335196018219, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.3359083831310272, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:western caribbean_X_walterboro'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.0, u'micro_accuracy': 0.0, u'precision': 0.0, u'label/mean': 1.0, u'average_loss': 1.317121982574463, 'post_export_metrics/example_count': 2.0, u'prediction/mean': 0.27397799491882324, u'auc_precision_recall': 0.9999995231628418, u'accuracy': 0.0}, 'slice': 'destination_X_geo_city:the_bahamas_X_oviedo'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.3702975809574127, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.3094711899757385, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:baja_mexico_X_st louis'}, {'metrics': {u'accuracy_baseline': 0.6666666865348816, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.6666666865348816, u'average_loss': 0.6975770592689514, 'post_export_metrics/example_count': 3.0, u'prediction/mean': 0.3659774363040924, u'auc_precision_recall': 0.9999995231628418, u'accuracy': 0.3333333432674408}, 'slice': 'destination_X_geo_city:western caribbean_X_carmel'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.1587851494550705, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.14682035148143768, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:the_bahamas_X_lithia springs'}, {'metrics': {u'accuracy_baseline': 1.0, u'recall': 0.0, u'auc': 0.9999990463256836, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.0, u'average_loss': 0.37711286544799805, 'post_export_metrics/example_count': 1.0, u'prediction/mean': 0.3141613304615021, u'auc_precision_recall': 0.0, u'accuracy': 1.0}, 'slice': 'destination_X_geo_city:southern_caribbean_X_des moines'}, {'metrics': {u'accuracy_baseline': 0.5, u'recall': 0.0, u'auc': 0.5, u'micro_accuracy': 0.5, u'precision': 0.0, u'label/mean': 0.5, u'average_loss': 0.7884140014648438, 'post_export_metrics/example_count': 4.0, u'prediction/mean': 0.27491751313209534, u'auc_precision_recall': 0.41666683554649353, u'accuracy': 0.5}, 'slice': 'destination_X_geo_city:eastern_caribbean_X_silver spring'}, {'metrics': {u'accuracy_ ...

# %%
for x in tfma_result_1.slicing_metrics:
    shape = np.shape(x[0])
    if shape[0] == 2 and shape[1] == 2:                
#         print(x[0][0][1], x[0][1][1], x[1]['post_export_metrics/example_count'])
        if x[1]['post_export_metrics/example_count'] > 20.0:
            if x[1]['auc'] - x[1]['accuracy'] > -.05:
                print(x[0][0][1], x[0][1][1], x[1]['accuracy'], x[1]['auc'])
# Out:
# ('western caribbean', 'columbus', 0.6666666865348816, 0.8398436307907104)
# ('western caribbean', 'chicago', 0.5348837375640869, 0.6500000357627869)
# ('eastern_caribbean', 'atlanta', 0.6896551847457886, 0.6749998927116394)
# ('the_bahamas', 'charlotte', 0.6470588445663452, 0.6628787517547607)
# ('western caribbean', 'austin', 0.529411792755127, 0.4894735813140869)
# ('the_bahamas', 'raleigh', 0.6190476417541504, 0.6490384340286255)
# ('western caribbean', 'tampa', 0.6857143044471741, 0.6704545021057129)

# %%
s = np.shape(tfma_result_1.slicing_metrics[0][0])

# %%
(0.43 - 0.68)
# Out:
# -0.25000000000000006
